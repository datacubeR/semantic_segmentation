# %%
# %load_ext tensorboard
# %tensorboard --logdir tb_logs/
# Out:
#       <iframe id="tensorboard-frame-ec22551b45c90a6" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-ec22551b45c90a6");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
import torch

ckpt = torch.load("l_checkpoints/Potsdam/unetpp/v1/last.ckpt", map_location="cpu")

print(ckpt["epoch"])
print(ckpt["global_step"])
# Out:
# 46
# 799
