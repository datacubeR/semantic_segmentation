# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from torchgeo.datasets import SeasoNet

train_data = SeasoNet(
    root="SeasonNet",
    split="train",
    seasons=frozenset({"Fall", "Snow", "Spring", "Summer", "Winter"}),
    grids=[1, 2],
    concat_seasons=1,
    download=True,
    checksum=False,
)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[7], line 3
#       1 from torchgeo.datasets import SeasoNet
#       2
# ----> 3 train_data = SeasoNet(
#       4     root="SeasonNet",
#       5     split="train",
#       6     seasons=frozenset({"Fall", "Snow", "Spring", "Summer", "Winter"}),
#
# File ~/Documents/deadtrees/.venv/lib/python3.13/site-packages/torchgeo/datasets/seasonet.py:259, in SeasoNet.__init__(self, root, split, seasons, bands, grids, concat_seasons, transforms, download, checksum)
#     256 self.download = download
#     257 self.checksum = checksum
# --> 259 self._verify()
#     261 self.channels = 0
#     262 for b in bands:
#
# File ~/Documents/deadtrees/.venv/lib/python3.13/site-packages/torchgeo/datasets/seasonet.py:389, in SeasoNet._verify(self)
#     387 # Download missing files
#     388 for file_info in missing:
# --> 389     download_url(
# ...
