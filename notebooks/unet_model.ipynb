# %%
import segmentation_models_pytorch as smp
from torchinfo import summary

# %%
model = smp.Unet(
    encoder_name="resnet101",
    encoder_weights="imagenet",
    in_channels=1,
    classes=3,
)
# Out:
# config.json:   0%|          | 0.00/156 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/179M [00:00<?, ?B/s]

# %%
summary(model)
# Out:
# ======================================================================
# Layer (type:depth-idx)                        Param #
# ======================================================================
# Unet                                          --
# ├─ResNetEncoder: 1-1                          --
# │    └─Conv2d: 2-1                            3,136
# │    └─BatchNorm2d: 2-2                       128
# │    └─ReLU: 2-3                              --
# │    └─MaxPool2d: 2-4                         --
# │    └─Sequential: 2-5                        --
# │    │    └─Bottleneck: 3-1                   75,008
# │    │    └─Bottleneck: 3-2                   70,400
# │    │    └─Bottleneck: 3-3                   70,400
# │    └─Sequential: 2-6                        --
# │    │    └─Bottleneck: 3-4                   379,392
# │    │    └─Bottleneck: 3-5                   280,064
# │    │    └─Bottleneck: 3-6                   280,064
# │    │    └─Bottleneck: 3-7                   280,064
# │    └─Sequential: 2-7                        --
# │    │    └─Bottleneck: 3-8                   1,512,448
# │    │    └─Bottleneck: 3-9                   1,117,184
# │    │    └─Bottleneck: 3-10                  1,117,184
# │    │    └─Bottleneck: 3-11                  1,117,184
# │    │    └─Bottleneck: 3-12                  1,117,184
# │    │    └─Bottleneck: 3-13                  1,117,184
# │    │    └─Bottleneck: 3-14                  1,117,184
# │    │    └─Bottleneck: 3-15                  1,117,184
# │    │    └─Bottleneck: 3-16                  1,117,184
# │    │    └─Bottleneck: 3-17                  1,117,184
# │    │    └─Bottleneck: 3-18                  1,117,184
# │    │    └─Bottleneck: 3-19                  1,117,184
# │    │    └─Bottleneck: 3-20                  1,117,184
# │    │    └─Bottleneck: 3-21                  1,117,184
# │    │    └─Bottleneck: 3-22                  1,117,184
# │    │    └─Bottleneck: 3-23                  1,117,184
# │    │    └─Bottleneck: 3-24                  1,117,184
# │    │    └─Bottleneck: 3-25                  1,117,184
# │    │    └─Bottleneck: 3-26                  1,117,184
# │    │    └─Bottleneck: 3-27                  1,117,184
# │    │    └─Bottleneck: 3-28                  1,117,184
# │    │    └─Bottleneck: 3-29                  1,117,184
# │    │    └─Bottleneck: 3-30                  1,117,184
# │    └─Sequential: 2-8                        --
# │    │    └─Bottleneck: 3-31                  6,039,552
# │    │    └─Bottleneck: 3-32                  4,462,592
# │    │    └─Bottleneck: 3-33                  4,462,592
# ├─UnetDecoder: 1-2                            --
# │    └─Identity: 2-9                          --
# │    └─ModuleList: 2-10                       --
# │    │    └─UnetDecoderBlock: 3-34            7,668,736
# │    │    └─UnetDecoderBlock: 3-35            1,032,704
# │    │    └─UnetDecoderBlock: 3-36            258,304
# │    │    └─UnetDecoderBlock: 3-37            46,208
# │    │    └─UnetDecoderBlock: 3-38            6,976
# ├─SegmentationHead: 1-3                       --
# │    └─Conv2d: 2-11                           435
# │    └─Identity: 2-12                         --
# │    └─Activation: 2-13                       --
# │    │    └─Identity: 3-39                    --
# ======================================================================
# Total params: 51,507,251
# Trainable params: 51,507,251
# Non-trainable params: 0
# ======================================================================

# %%
segformer = smp.Segformer(
    encoder_name="maxvit", encoder_weights="imagenet", in_channels=1, classes=3
)
summary(segformer)
# Out:
# config.json:   0%|          | 0.00/135 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/328M [00:00<?, ?B/s]
# ======================================================================
# Layer (type:depth-idx)                        Param #
# ======================================================================
# Segformer                                     --
# ├─MixVisionTransformerEncoder: 1-1            --
# │    └─OverlapPatchEmbed: 2-1                 --
# │    │    └─Conv2d: 3-1                       3,200
# │    │    └─LayerNorm: 3-2                    128
# │    └─OverlapPatchEmbed: 2-2                 --
# │    │    └─Conv2d: 3-3                       73,856
# │    │    └─LayerNorm: 3-4                    256
# │    └─OverlapPatchEmbed: 2-3                 --
# │    │    └─Conv2d: 3-5                       368,960
# │    │    └─LayerNorm: 3-6                    640
# │    └─OverlapPatchEmbed: 2-4                 --
# │    │    └─Conv2d: 3-7                       1,475,072
# │    │    └─LayerNorm: 3-8                    1,024
# │    └─Sequential: 2-5                        --
# │    │    └─Block: 3-9                        314,880
# │    │    └─Block: 3-10                       314,880
# │    │    └─Block: 3-11                       314,880
# │    └─LayerNorm: 2-6                         128
# │    └─Sequential: 2-7                        --
# │    │    └─Block: 3-12                       465,920
# │    │    └─Block: 3-13                       465,920
# │    │    └─Block: 3-14                       465,920
# │    │    └─Block: 3-15                       465,920
# │    │    └─Block: 3-16                       465,920
# │    │    └─Block: 3-17                       465,920
# │    └─LayerNorm: 2-8                         256
# │    └─Sequential: 2-9                        --
# │    │    └─Block: 3-18                       1,656,320
# │    │    └─Block: 3-19                       1,656,320
# │    │    └─Block: 3-20                       1,656,320
# │    │    └─Block: 3-21                       1,656,320
# │    │    └─Block: 3-22                       1,656,320
# │    │    └─Block: 3-23                       1,656,320
# │    │    └─Block: 3-24                       1,656,320
# │    │    └─Block: 3-25                       1,656,320
# │    │    └─Block: 3-26                       1,656,320
# │    │    └─Block: 3-27                       1,656,320
# │    │    └─Block: 3-28                       1,656,320
# │    │    └─Block: 3-29                       1,656,320
# │    │    └─Block: 3-30                       1,656,320
# │    │    └─Block: 3-31                       1,656,320
# │    │    └─Block: 3-32                       1,656,320
# │    │    └─Block: 3-33                       1,656,320
# │    │    └─Block: 3-34                       1,656,320
# │    │    └─Block: 3-35                       1,656,320
# │    │    └─Block: 3-36                       1,656,320
# │    │    └─Block: 3-37                       1,656,320
# │    │    └─Block: 3-38                       1,656,320
# │    │    └─Block: 3-39                       1,656,320
# │    │    └─Block: 3-40                       1,656,320
# │    │    └─Block: 3-41                       1,656,320
# │    │    └─Block: 3-42                       1,656,320
# │    │    └─Block: 3-43                       1,656,320
# │    │    └─Block: 3-44                       1,656,320
# │    │    └─Block: 3-45                       1,656,320
# │    │    └─Block: 3-46                       1,656,320
# │    │    └─Block: 3-47                       1,656,320
# │    │    └─Block: 3-48                       1,656,320
# │    │    └─Block: 3-49                       1,656,320
# │    │    └─Block: 3-50                       1,656,320
# │    │    └─Block: 3-51                       1,656,320
# │    │    └─Block: 3-52                       1,656,320
# │    │    └─Block: 3-53                       1,656,320
# │    │    └─Block: 3-54                       1,656,320
# │    │    └─Block: 3-55                       1,656,320
# │    │    └─Block: 3-56                       1,656,320
# │    │    └─Block: 3-57                       1,656,320
# │    └─LayerNorm: 2-10                        640
# │    └─Sequential: 2-11                       --
# │    │    └─Block: 3-58                       3,172,864
# │    │    └─Block: 3-59                       3,172,864
# │    │    └─Block: 3-60                       3,172,864
# │    └─LayerNorm: 2-12                        1,024
# ├─SegformerDecoder: 1-2                       --
# │    └─ModuleList: 2-13                       --
# │    │    └─MLP: 3-61                         131,328
# │    │    └─MLP: 3-62                         82,176
# │    │    └─MLP: 3-63                         33,024
# │    │    └─MLP: 3-64                         16,640
# │    └─Conv2dReLU: 2-14                       --
# │    │    └─Conv2d: 3-65                      262,144
# │    │    └─BatchNorm2d: 3-66                 512
# │    │    └─ReLU: 3-67                        --
# ├─SegmentationHead: 1-3                       --
# │    └─Conv2d: 2-15                           771
# │    └─UpsamplingBilinear2d: 2-16             --
# │    └─Activation: 2-17                       --
# │    │    └─Identity: 3-68                    --
# ======================================================================
# Total params: 81,963,331
# Trainable params: 81,963,331
# Non-trainable params: 0
# ======================================================================
