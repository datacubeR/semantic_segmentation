# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Vaihingen
#
# This one of the most common Baseline Datasets used for Image Segmentation. It includes 33 big images of different sizes. This dataset includes Channels NIR, R, G.

# %%
import glob
from utils import show_image_and_mask_from_rasterio

image_paths = glob.glob("Vaihingen_dataset/top/*.tif")
mask_paths = glob.glob(
    "Vaihingen_dataset/ISPRS_semantic_labeling_Vaihingen_ground_truth_COMPLETE/*.tif"
)
len(image_paths), len(mask_paths)
# Out:
# (33, 33)

# %%
import rasterio

image = rasterio.open(image_paths[3]).read().transpose(1, 2, 0)
image.shape
# Out:
# /home/datacuber/Documents/deadtrees/.venv/lib/python3.13/site-packages/rasterio/__init__.py:367: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dataset = DatasetReader(path, driver=driver, sharing=sharing, thread_safe=thread_safe, **kwargs)
# (2557, 1887, 3)

# %%
for image_path, mask_path in zip(image_paths[:5], mask_paths[:5]):
    show_image_and_mask_from_rasterio(image_path, mask_path)
# Out:
# /home/datacuber/Documents/deadtrees/.venv/lib/python3.13/site-packages/rasterio/__init__.py:367: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dataset = DatasetReader(path, driver=driver, sharing=sharing, thread_safe=thread_safe, **kwargs)
